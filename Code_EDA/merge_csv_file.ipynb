# %%
import pandas as pd

# %%
album_anger = pd.read_csv('/workspace/Data_Augumentation/Albumentation/label/train/albumentation_train_anger.csv')
album_happy = pd.read_csv('/workspace/Data_Augumentation/Albumentation/label/train/albumentation_train_happy.csv')
album_panic = pd.read_csv('/workspace/Data_Augumentation/Albumentation/label/train/albumentation_train_panic.csv')
album_sadness = pd.read_csv('/workspace/Data_Augumentation/Albumentation/label/train/albumentation_train_sadness.csv')

# %%
album_anger['path'] = '/workspace/Data_Augumentation/Albumentation/image/train/anger/'

# %%
album_anger.head()
# Out:
#                                             filename  maxX  maxY  minX  minY  \
# 0  albumentation_6oj439e3fbcc52759fb3093035b7c0ec...   359   433   181   144
# 1  albumentation_65rsfe402042f34319e10128c1ab9614...   445   576   222   157
# 2  albumentation_b1cbe34734870cc11c33334e02bea93a...   454   454   170    88
# 3  albumentation_llfycc0aa29599cc63cace3610fdaaad...   640   640   347   195
# 4  albumentation_3hww73b70615461a7336d0383b53582f...   348   494    83    64
#
#   faceExp_uploader                                               path
# 0               분노  /workspace/Data_Augumentation/Albumentation/im...
# 1               분노  /workspace/Data_Augumentation/Albumentation/im...
# 2               분노  /workspace/Data_Augumentation/Albumentation/im...
# 3               분노  /workspace/Data_Augumentation/Albumentation/im...
# 4               분노  /workspace/Data_Augumentation/Albumentation/im...

# %%
album_happy['path'] = '/workspace/Data_Augumentation/Albumentation/image/train/happy/'
album_panic['path'] = '/workspace/Data_Augumentation/Albumentation/image/train/panic/'
album_sadness['path'] = '/workspace/Data_Augumentation/Albumentation/image/train/sadness/'

# %%
# 세로로 결합 (행 기준)
df = pd.concat([album_anger, album_happy, album_panic, album_sadness], ignore_index=True)

df.head()
# Out:
#                                             filename  maxX  maxY  minX  minY  \
# 0  albumentation_6oj439e3fbcc52759fb3093035b7c0ec...   359   433   181   144
# 1  albumentation_65rsfe402042f34319e10128c1ab9614...   445   576   222   157
# 2  albumentation_b1cbe34734870cc11c33334e02bea93a...   454   454   170    88
# 3  albumentation_llfycc0aa29599cc63cace3610fdaaad...   640   640   347   195
# 4  albumentation_3hww73b70615461a7336d0383b53582f...   348   494    83    64
#
#   faceExp_uploader                                               path
# 0               분노  /workspace/Data_Augumentation/Albumentation/im...
# 1               분노  /workspace/Data_Augumentation/Albumentation/im...
# 2               분노  /workspace/Data_Augumentation/Albumentation/im...
# 3               분노  /workspace/Data_Augumentation/Albumentation/im...
# 4               분노  /workspace/Data_Augumentation/Albumentation/im...

# %%
df.tail()
# Out:
#                                                filename  maxX  maxY  minX  \
# 5988  albumentation_ha8z5c205df254ec0e462951a5ee3312...   515   583   263
# 5989  albumentation_6n6y2563675de5f53e1570a25fa615ea...   481   485   225
# 5990  albumentation_t4e50b083ffe45071ea1871e1d433e00...   396   358   220
# 5991  albumentation_ob661e0f447bb24def8a55fe0ddabba4...   398   532   239
# 5992  albumentation_zygcc2ae65d241fa88e458f5a933aa46...   444   435   184
#
#       minY faceExp_uploader                                               path
# 5988   145               슬픔  /workspace/Data_Augumentation/Albumentation/im...
# 5989   142               슬픔  /workspace/Data_Augumentation/Albumentation/im...
# 5990    44               슬픔  /workspace/Data_Augumentation/Albumentation/im...
# 5991    64               슬픔  /workspace/Data_Augumentation/Albumentation/im...
# 5992   183               슬픔  /workspace/Data_Augumentation/Albumentation/im...

# %%
df.to_csv('/workspace/Data_Augumentation/Albumentation/label/train/albumentation_train.csv', index=False)

# %%
val_anger = pd.read_csv('/workspace/#Ub370#Uc774#Ud130/Data/label/val/val_anger.csv')
val_happy = pd.read_csv('/workspace/#Ub370#Uc774#Ud130/Data/label/val/val_happy.csv')
val_panic = pd.read_csv('/workspace/#Ub370#Uc774#Ud130/Data/label/val/val_panic.csv')
val_sadness = pd.read_csv('/workspace/#Ub370#Uc774#Ud130/Data/label/val/val_sadness.csv')

# %%
val_anger.head()
# Out:
#                                             filename faceExp_uploader  \
# 0  7uji1c8ab7778bc286c3cd90077847f9a906f00b210838...               분노
# 1  qokw201acdd0f74c7794a9ddcbc9cabdf9c79dd711cbed...               분노
# 2  tzg8926848c43051598de35ece59588857ce02af169954...               분노
# 3  w4vh9e941e6c400f03df009496eaa1f639e73d8ec8104c...               분노
# 4  qii07233b67c5d41cb109e19d2d14309cb177b43f40698...               분노
#
#    annot_A.boxes.maxX  annot_A.boxes.maxY  annot_A.boxes.minX  \
# 0         2333.655000         1321.890300         1635.013000
# 1         1697.420898         1640.031806          963.564059
# 2         2078.563500         1241.851000         1171.624000
# 3         1921.776100         1827.133400          889.979740
# 4         2855.292176         2190.112808         1905.411155
#
#    annot_A.boxes.minY  annot_B.boxes.maxX  annot_B.boxes.maxY  \
# 0          333.644780         2333.464426         1321.890300
# ...

# %%
val_anger['path'] = '/workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/'
val_happy['path'] = '/workspace/#Ub370#Uc774#Ud130/Data/img/val/happy/'
val_panic['path'] = '/workspace/#Ub370#Uc774#Ud130/Data/img/val/panic/'
val_sadness['path'] = '/workspace/#Ub370#Uc774#Ud130/Data/img/val/sadness/'

# %%
val_anger.head()
# Out:
#                                             filename faceExp_uploader  \
# 0  7uji1c8ab7778bc286c3cd90077847f9a906f00b210838...               분노
# 1  qokw201acdd0f74c7794a9ddcbc9cabdf9c79dd711cbed...               분노
# 2  tzg8926848c43051598de35ece59588857ce02af169954...               분노
# 3  w4vh9e941e6c400f03df009496eaa1f639e73d8ec8104c...               분노
# 4  qii07233b67c5d41cb109e19d2d14309cb177b43f40698...               분노
#
#    annot_A.boxes.maxX  annot_A.boxes.maxY  annot_A.boxes.minX  \
# 0         2333.655000         1321.890300         1635.013000
# 1         1697.420898         1640.031806          963.564059
# 2         2078.563500         1241.851000         1171.624000
# 3         1921.776100         1827.133400          889.979740
# 4         2855.292176         2190.112808         1905.411155
#
#    annot_A.boxes.minY  annot_B.boxes.maxX  annot_B.boxes.maxY  \
# 0          333.644780         2333.464426         1321.890300
# ...

# %%
val_anger = val_anger[['filename', 'avg_box.maxX', 'avg_box.maxY', 'avg_box.minX', 'avg_box.minY', 'faceExp_uploader', 'path']]
val_happy = val_happy[['filename', 'avg_box.maxX', 'avg_box.maxY', 'avg_box.minX', 'avg_box.minY', 'faceExp_uploader', 'path']]
val_panic = val_panic[['filename', 'avg_box.maxX', 'avg_box.maxY', 'avg_box.minX', 'avg_box.minY', 'faceExp_uploader', 'path']]
val_sadness = val_sadness[['filename', 'avg_box.maxX', 'avg_box.maxY', 'avg_box.minX', 'avg_box.minY', 'faceExp_uploader', 'path']]

# %%
val_anger.head()
# Out:
#                                             filename  avg_box.maxX  \
# 0  7uji1c8ab7778bc286c3cd90077847f9a906f00b210838...   2333.591475
# 1  qokw201acdd0f74c7794a9ddcbc9cabdf9c79dd711cbed...   1715.931082
# 2  tzg8926848c43051598de35ece59588857ce02af169954...   2086.550258
# 3  w4vh9e941e6c400f03df009496eaa1f639e73d8ec8104c...   1921.806415
# 4  qii07233b67c5d41cb109e19d2d14309cb177b43f40698...   2862.368054
#
#    avg_box.maxY  avg_box.minX  avg_box.minY faceExp_uploader  \
# 0   1321.890300   1622.256256    333.644780               분노
# 1   1671.184168    950.156456    708.129637               분노
# 2   1233.893825   1186.184674      0.223078               분노
# 3   1827.133400    897.907320    531.482300               분노
# 4   2193.519055   1916.583700    881.268143               분노
#
#                                                 path
# 0  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# 1  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# ...

# %%
val_anger = val_anger.rename(columns={'avg_box.maxX': 'maxX', 'avg_box.maxY': 'maxY', 'avg_box.minX': 'minX', 'avg_box.minY': 'minY'})

# %%
val_anger.head()
# Out:
#                                             filename         maxX  \
# 0  7uji1c8ab7778bc286c3cd90077847f9a906f00b210838...  2333.591475
# 1  qokw201acdd0f74c7794a9ddcbc9cabdf9c79dd711cbed...  1715.931082
# 2  tzg8926848c43051598de35ece59588857ce02af169954...  2086.550258
# 3  w4vh9e941e6c400f03df009496eaa1f639e73d8ec8104c...  1921.806415
# 4  qii07233b67c5d41cb109e19d2d14309cb177b43f40698...  2862.368054
#
#           maxY         minX        minY faceExp_uploader  \
# 0  1321.890300  1622.256256  333.644780               분노
# 1  1671.184168   950.156456  708.129637               분노
# 2  1233.893825  1186.184674    0.223078               분노
# 3  1827.133400   897.907320  531.482300               분노
# 4  2193.519055  1916.583700  881.268143               분노
#
#                                                 path
# 0  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# 1  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# 2  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# ...

# %%
val_happy = val_happy.rename(columns={'avg_box.maxX': 'maxX', 'avg_box.maxY': 'maxY', 'avg_box.minX': 'minX', 'avg_box.minY': 'minY'})
val_panic = val_panic.rename(columns={'avg_box.maxX': 'maxX', 'avg_box.maxY': 'maxY', 'avg_box.minX': 'minX', 'avg_box.minY': 'minY'})
val_sadness = val_sadness.rename(columns={'avg_box.maxX': 'maxX', 'avg_box.maxY': 'maxY', 'avg_box.minX': 'minX', 'avg_box.minY': 'minY'})

# %%
# 세로로 결합 (행 기준)
df_1 = pd.concat([val_anger, val_happy, val_panic, val_sadness], ignore_index=True)

df_1.head()
# Out:
#                                             filename         maxX  \
# 0  7uji1c8ab7778bc286c3cd90077847f9a906f00b210838...  2333.591475
# 1  qokw201acdd0f74c7794a9ddcbc9cabdf9c79dd711cbed...  1715.931082
# 2  tzg8926848c43051598de35ece59588857ce02af169954...  2086.550258
# 3  w4vh9e941e6c400f03df009496eaa1f639e73d8ec8104c...  1921.806415
# 4  qii07233b67c5d41cb109e19d2d14309cb177b43f40698...  2862.368054
#
#           maxY         minX        minY faceExp_uploader  \
# 0  1321.890300  1622.256256  333.644780               분노
# 1  1671.184168   950.156456  708.129637               분노
# 2  1233.893825  1186.184674    0.223078               분노
# 3  1827.133400   897.907320  531.482300               분노
# 4  2193.519055  1916.583700  881.268143               분노
#
#                                                 path
# 0  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# 1  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# 2  /workspace/#Ub370#Uc774#Ud130/Data/img/val/anger/
# ...

# %%
df_1.to_csv('/workspace/#Ub370#Uc774#Ud130/Data/label/val/val.csv', index=False)
