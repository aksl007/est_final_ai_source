# %%
import tensorflow as tf
print(tf.__version__)  # TensorFlow 버전 확인
print("CUDA Available: ", tf.test.is_built_with_cuda())  # CUDA 사용 가능 여부 확인
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2024-12-25 10:38:16.138813: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-25 10:38:16.138889: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-25 10:38:16.138943: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.14.0
# CUDA Available:  True
# Num GPUs Available:  1

# %%
import numpy as np
import cv2
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from mtcnn import MTCNN
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# 테스트 데이터 로드
df_test = pd.read_csv('/workspace/#Ub370#Uc774#Ud130/test/label/test.csv')

# 이미지 경로 열 생성
df_test['img_path'] = df_test['path'] + df_test['filename']

# %%
# 데이터 업로드 제너레이터 설정
target_size = (224,224)     # 모델 입력에 맞는 사이즈 설정

# ImageDataGenerator 정의 
datagen = ImageDataGenerator() 

# test 데이터 generator 정의
test_generator = datagen.flow_from_dataframe(
    dataframe=df_test,                # Pandas DataFrame with image paths and labels
    directory=None,                   # Root directory for relative image paths
    x_col='img_path',                 # Column name in DataFrame containing image file paths
    y_col='faceExp_uploader',         # Column name in DataFrame containing labels
    target_size=target_size,           # Resize all images to (224, 224) pixels
    batch_size=32,                    # Number of images per batch
    class_mode='categorical'          # Multi-class classification: output one-hot encoded labels
)

print("Test Generator Class Indices:", test_generator.class_indices)
# Out:
# Found 1200 validated image filenames belonging to 4 classes.
# Test Generator Class Indices: {'기쁨': 0, '당황': 1, '분노': 2, '슬픔': 3}

# %%
# 바운딩 박스 내부 이미지를 크롭하고 모델에 입력
def crop_and_predict(image, detections, emotion_classes, emotion_model):
    predictions = []
    for detection in detections:
        x, y, width, height = detection['box']
        x, y = max(x, 0), max(y, 0)  # 음수 좌표 방지
        face = image[y:y+height, x:x+width]  # 얼굴 영역 크롭
        face = tf.image.resize(face, (224, 224))  # 모델 입력 크기로 조정
        face = img_to_array(face) / 255.0  # 정규화
        face = np.expand_dims(face, axis=0)  # 배치 차원 추가
        
        # 감정 예측
        prediction = emotion_model.predict(face)
        emotion_index = np.argmax(prediction)
        emotion_label = emotion_classes[emotion_index]
        predictions.append((detection['box'], emotion_label, prediction[0][emotion_index]))

    return predictions

# MTCNN 및 감정 분류 모델 예측 결과와 실제 레이블 비교 함수
def evaluate_predictions(generator, detector, emotion_classes, emotion_model):
    y_true = []  # 실제 레이블
    y_pred = []  # 예측 레이블
    class_indices = generator.class_indices
    index_to_label = {v: k for k, v in class_indices.items()}  # 인덱스를 레이블로 변환

    for batch_index in range(len(generator)):
        images, labels = generator[batch_index]  # 배치 단위로 이미지와 레이블 가져오기
        
        for i, (image, label) in enumerate(zip(images, labels)):

            # MTCNN으로 얼굴 탐지
            detections = detector.detect_faces(image)
            if not detections:
                print(f"Image {batch_index * generator.batch_size + i}: No face detected.")
                continue
            
            # 바운딩 박스 내부 얼굴 감정 예측
            predictions = crop_and_predict(image, detections, emotion_classes, emotion_model)

            # 다중 얼굴 탐지 중 첫 번째 얼굴 기준으로 비교 (여러 얼굴 처리 필요 시 수정)
            if predictions:
                _, predicted_emotion, _ = predictions[0]  # 첫 번째 얼굴의 예측값 가져오기
                y_pred.append(predicted_emotion)
                true_label_index = np.argmax(label)  # 실제 레이블 (원핫 인코딩)
                true_label = index_to_label[true_label_index]
                y_true.append(true_label)
            
                print(f"Image {batch_index * generator.batch_size + i}:")
                print(f"  True: {true_label}, Predicted: {predicted_emotion}")
            else:
                print(f"Image {batch_index * generator.batch_size + i}: No emotion predicted.")
    
    # 결과 출력
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=emotion_classes))

    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_true, y_pred, labels=emotion_classes)
    print(cm)

# %%
# Load MTCNN for face detection
detector = MTCNN()

# Load the pre-trained MobileNet model
mobilenet_model = tf.keras.models.load_model('/workspace/uk/Emotion_Classifier_MoblieNet.h5')

# 실행
evaluate_predictions(test_generator, detector, ['기쁨', '당황', '분노', '슬픔'], mobilenet_model)
# Out:
# 2024-12-25 10:38:34.349239: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14297 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:04:00.0, compute capability: 8.6
# 2024-12-25 10:38:41.785852: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 1/1 [==============================] - 1s 1s/step
# Image 0:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 33ms/step
# Image 1:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 32ms/step
# Image 2:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 3:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 4:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 5:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 6:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 7:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 8:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 9:
#   True: 당황, Predicted: 분노
# Image 10: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 11:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 12:
#   True: 슬픔, Predicted: 기쁨
# Image 13: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 14:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 30ms/step
# Image 15:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# Image 16:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 17:
#   True: 슬픔, Predicted: 기쁨
# Image 18: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 19:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 20:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 21:
#   True: 기쁨, Predicted: 기쁨
# Image 22: No face detected.
# Image 23: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 24:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 25:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 31ms/step
# Image 26:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 27:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 28:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 29:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 30:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 32ms/step
# Image 31:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 32:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 33:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 34:
#   True: 분노, Predicted: 분노
# Image 35: No face detected.
# Image 36: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 37:
#   True: 분노, Predicted: 분노
# Image 38: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 39:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 40:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 41:
#   True: 분노, Predicted: 당황
# 1/1 [==============================] - 0s 39ms/step
# Image 42:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 43:
#   True: 분노, Predicted: 분노
# Image 44: No face detected.
# Image 45: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 46:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 47:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 48:
#   True: 슬픔, Predicted: 기쁨
# Image 49: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 50:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 36ms/step
# Image 51:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 52:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 53:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 54:
#   True: 당황, Predicted: 슬픔
# Image 55: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 56:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 57:
#   True: 슬픔, Predicted: 기쁨
# Image 58: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 59:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 37ms/step
# Image 60:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 61:
#   True: 당황, Predicted: 기쁨
# Image 62: No face detected.
# Image 63: No face detected.
# Image 64: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 65:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 66:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 67:
#   True: 당황, Predicted: 기쁨
# Image 68: No face detected.
# Image 69: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 70:
#   True: 분노, Predicted: 당황
# 1/1 [==============================] - 0s 31ms/step
# Image 71:
#   True: 기쁨, Predicted: 기쁨
# Image 72: No face detected.
# Image 73: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 74:
#   True: 슬픔, Predicted: 슬픔
# Image 75: No face detected.
# Image 76: No face detected.
# 1/1 [==============================] - 0s 29ms/step
# Image 77:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 78:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 30ms/step
# Image 79:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 80:
#   True: 분노, Predicted: 기쁨
# Image 81: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 82:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 32ms/step
# Image 83:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 84:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 31ms/step
# Image 85:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 86:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 31ms/step
# Image 87:
#   True: 당황, Predicted: 기쁨
# Image 88: No face detected.
# Image 89: No face detected.
# Image 90: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 91:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 31ms/step
# Image 92:
#   True: 슬픔, Predicted: 기쁨
# Image 93: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 94:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 95:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 96:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 97:
#   True: 기쁨, Predicted: 기쁨
# Image 98: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 99:
#   True: 슬픔, Predicted: 분노
# Image 100: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 101:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 102:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 103:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 104:
#   True: 기쁨, Predicted: 기쁨
# Image 105: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 106:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 107:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 108:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 109:
#   True: 분노, Predicted: 분노
# Image 110: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 111:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 112:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 113:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 114:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 115:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 116:
#   True: 슬픔, Predicted: 기쁨
# Image 117: No face detected.
# Image 118: No face detected.
# Image 119: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 120:
#   True: 슬픔, Predicted: 기쁨
# Image 121: No face detected.
# Image 122: No face detected.
# Image 123: No face detected.
# Image 124: No face detected.
# Image 125: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 126:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 127:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 34ms/step
# Image 128:
#   True: 기쁨, Predicted: 기쁨
# Image 129: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 130:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 131:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 132:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# Image 133:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 134:
#   True: 기쁨, Predicted: 기쁨
# Image 135: No face detected.
# Image 136: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 137:
#   True: 당황, Predicted: 기쁨
# Image 138: No face detected.
# Image 139: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 140:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 141:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 142:
#   True: 분노, Predicted: 기쁨
# Image 143: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 144:
#   True: 슬픔, Predicted: 기쁨
# Image 145: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 146:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 147:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 148:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 38ms/step
# Image 149:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 150:
#   True: 분노, Predicted: 당황
# Image 151: No face detected.
# Image 152: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 153:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 38ms/step
# Image 154:
#   True: 당황, Predicted: 기쁨
# Image 155: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 156:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 157:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 158:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 159:
#   True: 당황, Predicted: 기쁨
# Image 160: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 161:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 162:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 32ms/step
# Image 163:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 164:
#   True: 당황, Predicted: 기쁨
# Image 165: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 166:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 167:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 168:
#   True: 슬픔, Predicted: 당황
# Image 169: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 170:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 32ms/step
# Image 171:
#   True: 기쁨, Predicted: 슬픔
# Image 172: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 173:
#   True: 분노, Predicted: 슬픔
# Image 174: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 175:
#   True: 분노, Predicted: 기쁨
# Image 176: No face detected.
# Image 177: No face detected.
# Image 178: No face detected.
# 1/1 [==============================] - 0s 34ms/step
# Image 179:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 180:
#   True: 기쁨, Predicted: 기쁨
# Image 181: No face detected.
# Image 182: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 183:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 184:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 31ms/step
# Image 185:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 186:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 187:
#   True: 당황, Predicted: 기쁨
# Image 188: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 189:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 32ms/step
# Image 190:
#   True: 당황, Predicted: 기쁨
# Image 191: No face detected.
# 1/1 [==============================] - 0s 34ms/step
# Image 192:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 193:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 194:
#   True: 슬픔, Predicted: 기쁨
# Image 195: No face detected.
# Image 196: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 197:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 198:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 199:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 42ms/step
# Image 200:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 35ms/step
# Image 201:
#   True: 분노, Predicted: 기쁨
# Image 202: No face detected.
# Image 203: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 204:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 205:
#   True: 당황, Predicted: 기쁨
# Image 206: No face detected.
# 1/1 [==============================] - 0s 42ms/step
# Image 207:
#   True: 기쁨, Predicted: 기쁨
# Image 208: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 209:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 210:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 36ms/step
# Image 211:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 41ms/step
# Image 212:
#   True: 슬픔, Predicted: 기쁨
# Image 213: No face detected.
# Image 214: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 215:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 216:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 217:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 218:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 219:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 220:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 221:
#   True: 당황, Predicted: 기쁨
# Image 222: No face detected.
# Image 223: No face detected.
# 1/1 [==============================] - 0s 42ms/step
# Image 224:
#   True: 기쁨, Predicted: 기쁨
# Image 225: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 226:
#   True: 당황, Predicted: 기쁨
# Image 227: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 228:
#   True: 기쁨, Predicted: 슬픔
# 1/1 [==============================] - 0s 38ms/step
# Image 229:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 37ms/step
# Image 230:
#   True: 기쁨, Predicted: 슬픔
# Image 231: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 232:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 233:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 39ms/step
# Image 234:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 235:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 236:
#   True: 분노, Predicted: 기쁨
# Image 237: No face detected.
# Image 238: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 239:
#   True: 기쁨, Predicted: 기쁨
# Image 240: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 241:
#   True: 기쁨, Predicted: 기쁨
# Image 242: No face detected.
# Image 243: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 244:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 245:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 246:
#   True: 분노, Predicted: 기쁨
# Image 247: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 248:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 249:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 250:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 251:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 40ms/step
# Image 252:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 38ms/step
# Image 253:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 254:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 36ms/step
# Image 255:
#   True: 기쁨, Predicted: 기쁨
# Image 256: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 257:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 258:
#   True: 당황, Predicted: 슬픔
# Image 259: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 260:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 261:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 262:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 263:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 264:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 265:
#   True: 기쁨, Predicted: 기쁨
# Image 266: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 267:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 268:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 39ms/step
# Image 269:
#   True: 기쁨, Predicted: 기쁨
# Image 270: No face detected.
# Image 271: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 272:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 38ms/step
# Image 273:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 274:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 37ms/step
# Image 275:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 276:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 277:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 278:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 279:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 280:
#   True: 당황, Predicted: 기쁨
# Image 281: No face detected.
# Image 282: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 283:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 284:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 285:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 286:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 287:
#   True: 기쁨, Predicted: 기쁨
# Image 288: No face detected.
# 1/1 [==============================] - 0s 45ms/step
# Image 289:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 290:
#   True: 슬픔, Predicted: 분노
# Image 291: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 292:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 293:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 294:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 36ms/step
# Image 295:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 296:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 297:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 298:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 299:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 300:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 36ms/step
# Image 301:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 302:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 303:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 304:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 305:
#   True: 분노, Predicted: 분노
# Image 306: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 307:
#   True: 분노, Predicted: 기쁨
# Image 308: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 309:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 310:
#   True: 기쁨, Predicted: 기쁨
# Image 311: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 312:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 313:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 38ms/step
# Image 314:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 39ms/step
# Image 315:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 316:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 317:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 318:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 319:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 320:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 321:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 322:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 323:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 324:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 325:
#   True: 기쁨, Predicted: 기쁨
# Image 326: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 327:
#   True: 슬픔, Predicted: 기쁨
# Image 328: No face detected.
# Image 329: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 330:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 331:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 332:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 333:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 334:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 335:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 336:
#   True: 기쁨, Predicted: 기쁨
# Image 337: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 338:
#   True: 당황, Predicted: 기쁨
# Image 339: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 340:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 341:
#   True: 분노, Predicted: 기쁨
# Image 342: No face detected.
# Image 343: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 344:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 345:
#   True: 당황, Predicted: 기쁨
# Image 346: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 347:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 348:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 349:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 350:
#   True: 슬픔, Predicted: 기쁨
# Image 351: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 352:
#   True: 당황, Predicted: 기쁨
# Image 353: No face detected.
# Image 354: No face detected.
# Image 355: No face detected.
# Image 356: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 357:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 358:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 359:
#   True: 당황, Predicted: 슬픔
# Image 360: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 361:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 362:
#   True: 분노, Predicted: 기쁨
# Image 363: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 364:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 365:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 366:
#   True: 당황, Predicted: 기쁨
# Image 367: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 368:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 369:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 370:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 371:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 372:
#   True: 기쁨, Predicted: 슬픔
# 1/1 [==============================] - 0s 36ms/step
# Image 373:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 374:
#   True: 분노, Predicted: 기쁨
# Image 375: No face detected.
# Image 376: No face detected.
# 1/1 [==============================] - 0s 41ms/step
# Image 377:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 378:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 379:
#   True: 분노, Predicted: 당황
# Image 380: No face detected.
# Image 381: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 382:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 35ms/step
# Image 383:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 384:
#   True: 기쁨, Predicted: 기쁨
# Image 385: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 386:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 31ms/step
# Image 387:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 388:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 389:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 390:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 391:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 392:
#   True: 슬픔, Predicted: 기쁨
# Image 393: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 394:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 395:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 36ms/step
# Image 396:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 397:
#   True: 슬픔, Predicted: 기쁨
# Image 398: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 399:
#   True: 분노, Predicted: 분노
# Image 400: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 401:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 402:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 403:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 404:
#   True: 슬픔, Predicted: 기쁨
# Image 405: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 406:
#   True: 기쁨, Predicted: 기쁨
# Image 407: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 408:
#   True: 기쁨, Predicted: 기쁨
# Image 409: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 410:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 411:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 39ms/step
# Image 412:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 413:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 51ms/step
# Image 414:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 415:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 416:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 417:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 418:
#   True: 당황, Predicted: 기쁨
# Image 419: No face detected.
# Image 420: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 421:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 422:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 33ms/step
# Image 423:
#   True: 슬픔, Predicted: 기쁨
# Image 424: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 425:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 426:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 427:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 30ms/step
# Image 428:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 30ms/step
# Image 429:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 430:
#   True: 기쁨, Predicted: 기쁨
# Image 431: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 432:
#   True: 슬픔, Predicted: 기쁨
# Image 433: No face detected.
# Image 434: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 435:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 32ms/step
# Image 436:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 437:
#   True: 기쁨, Predicted: 기쁨
# Image 438: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 439:
#   True: 슬픔, Predicted: 기쁨
# Image 440: No face detected.
# Image 441: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 442:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 443:
#   True: 당황, Predicted: 기쁨
# Image 444: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 445:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 446:
#   True: 기쁨, Predicted: 기쁨
# Image 447: No face detected.
# Image 448: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 449:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 450:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 451:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 31ms/step
# Image 452:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 453:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 454:
#   True: 슬픔, Predicted: 기쁨
# Image 455: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 456:
#   True: 분노, Predicted: 기쁨
# Image 457: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 458:
#   True: 슬픔, Predicted: 기쁨
# Image 459: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 460:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 461:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 29ms/step
# Image 462:
#   True: 분노, Predicted: 기쁨
# Image 463: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 464:
#   True: 분노, Predicted: 기쁨
# Image 465: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 466:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 467:
#   True: 분노, Predicted: 기쁨
# Image 468: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 469:
#   True: 슬픔, Predicted: 기쁨
# Image 470: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 471:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 30ms/step
# Image 472:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 473:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 474:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 475:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 476:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 477:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 478:
#   True: 분노, Predicted: 기쁨
# Image 479: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 480:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 481:
#   True: 분노, Predicted: 슬픔
# Image 482: No face detected.
# 1/1 [==============================] - 0s 45ms/step
# Image 483:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 484:
#   True: 슬픔, Predicted: 기쁨
# Image 485: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 486:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 487:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 33ms/step
# Image 488:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 489:
#   True: 기쁨, Predicted: 기쁨
# Image 490: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 491:
#   True: 슬픔, Predicted: 기쁨
# Image 492: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 493:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 494:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 495:
#   True: 기쁨, Predicted: 기쁨
# Image 496: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 497:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 498:
#   True: 슬픔, Predicted: 당황
# 1/1 [==============================] - 0s 40ms/step
# Image 499:
#   True: 슬픔, Predicted: 기쁨
# Image 500: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 501:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 502:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 503:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 504:
#   True: 분노, Predicted: 기쁨
# Image 505: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 506:
#   True: 분노, Predicted: 기쁨
# Image 507: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 508:
#   True: 분노, Predicted: 기쁨
# Image 509: No face detected.
# Image 510: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 511:
#   True: 당황, Predicted: 기쁨
# Image 512: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 513:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 514:
#   True: 기쁨, Predicted: 기쁨
# Image 515: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 516:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 33ms/step
# Image 517:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 518:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 519:
#   True: 기쁨, Predicted: 기쁨
# Image 520: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 521:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 522:
#   True: 슬픔, Predicted: 기쁨
# Image 523: No face detected.
# 1/1 [==============================] - 0s 29ms/step
# Image 524:
#   True: 분노, Predicted: 기쁨
# Image 525: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 526:
#   True: 당황, Predicted: 기쁨
# Image 527: No face detected.
# 1/1 [==============================] - 0s 34ms/step
# Image 528:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 529:
#   True: 슬픔, Predicted: 기쁨
# Image 530: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 531:
#   True: 기쁨, Predicted: 기쁨
# Image 532: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 533:
#   True: 기쁨, Predicted: 기쁨
# Image 534: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 535:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 536:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 537:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 538:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 539:
#   True: 기쁨, Predicted: 기쁨
# Image 540: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 541:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 38ms/step
# Image 542:
#   True: 분노, Predicted: 당황
# Image 543: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 544:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 545:
#   True: 기쁨, Predicted: 기쁨
# Image 546: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 547:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 30ms/step
# Image 548:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 549:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 550:
#   True: 슬픔, Predicted: 기쁨
# Image 551: No face detected.
# Image 552: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 553:
#   True: 분노, Predicted: 기쁨
# Image 554: No face detected.
# Image 555: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 556:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 32ms/step
# Image 557:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 558:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 32ms/step
# Image 559:
#   True: 분노, Predicted: 분노
# Image 560: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 561:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 30ms/step
# Image 562:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 563:
#   True: 분노, Predicted: 기쁨
# Image 564: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 565:
#   True: 당황, Predicted: 당황
# Image 566: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 567:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 31ms/step
# Image 568:
#   True: 슬픔, Predicted: 기쁨
# Image 569: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Image 570:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 571:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 30ms/step
# Image 572:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 573:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 33ms/step
# Image 574:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 30ms/step
# Image 575:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 576:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 577:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 578:
#   True: 분노, Predicted: 분노
# Image 579: No face detected.
# Image 580: No face detected.
# Image 581: No face detected.
# Image 582: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 583:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 584:
#   True: 슬픔, Predicted: 기쁨
# Image 585: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 586:
#   True: 분노, Predicted: 당황
# 1/1 [==============================] - 0s 37ms/step
# Image 587:
#   True: 당황, Predicted: 분노
# Image 588: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 589:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 590:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 37ms/step
# Image 591:
#   True: 분노, Predicted: 분노
# Image 592: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 593:
#   True: 분노, Predicted: 기쁨
# Image 594: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 595:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 596:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 597:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 598:
#   True: 슬픔, Predicted: 기쁨
# Image 599: No face detected.
# Image 600: No face detected.
# 1/1 [==============================] - 0s 42ms/step
# Image 601:
#   True: 분노, Predicted: 기쁨
# Image 602: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 603:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 37ms/step
# Image 604:
#   True: 분노, Predicted: 기쁨
# Image 605: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 606:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 607:
#   True: 당황, Predicted: 기쁨
# Image 608: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 609:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 610:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 611:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 612:
#   True: 당황, Predicted: 기쁨
# Image 613: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 614:
#   True: 기쁨, Predicted: 기쁨
# Image 615: No face detected.
# Image 616: No face detected.
# Image 617: No face detected.
# Image 618: No face detected.
# Image 619: No face detected.
# Image 620: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 621:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 622:
#   True: 당황, Predicted: 기쁨
# Image 623: No face detected.
# Image 624: No face detected.
# Image 625: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 626:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 35ms/step
# Image 627:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 36ms/step
# Image 628:
#   True: 기쁨, Predicted: 기쁨
# Image 629: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 630:
#   True: 기쁨, Predicted: 분노
# Image 631: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 632:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 633:
#   True: 당황, Predicted: 기쁨
# Image 634: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 635:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 636:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 637:
#   True: 당황, Predicted: 분노
# Image 638: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 639:
#   True: 기쁨, Predicted: 슬픔
# 1/1 [==============================] - 0s 33ms/step
# Image 640:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 641:
#   True: 당황, Predicted: 분노
# Image 642: No face detected.
# 1/1 [==============================] - 0s 32ms/step
# Image 643:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 644:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 645:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 31ms/step
# Image 646:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 647:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 32ms/step
# Image 648:
#   True: 분노, Predicted: 기쁨
# Image 649: No face detected.
# 1/1 [==============================] - 0s 34ms/step
# Image 650:
#   True: 당황, Predicted: 기쁨
# Image 651: No face detected.
# 1/1 [==============================] - 0s 29ms/step
# Image 652:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 32ms/step
# Image 653:
#   True: 기쁨, Predicted: 기쁨
# Image 654: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 655:
#   True: 기쁨, Predicted: 기쁨
# Image 656: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 657:
#   True: 기쁨, Predicted: 기쁨
# Image 658: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 659:
#   True: 슬픔, Predicted: 슬픔
# 1/1 [==============================] - 0s 31ms/step
# Image 660:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 661:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 662:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 663:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 664:
#   True: 기쁨, Predicted: 분노
# Image 665: No face detected.
# 1/1 [==============================] - 0s 34ms/step
# Image 666:
#   True: 당황, Predicted: 기쁨
# Image 667: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 668:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 34ms/step
# Image 669:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 29ms/step
# Image 670:
#   True: 당황, Predicted: 기쁨
# Image 671: No face detected.
# Image 672: No face detected.
# ...
# Image 985: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 986:
#   True: 기쁨, Predicted: 분노
# Image 987: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 988:
#   True: 기쁨, Predicted: 분노
# Image 989: No face detected.
# Image 990: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 991:
#   True: 기쁨, Predicted: 기쁨
# Image 992: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 993:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 994:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 995:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 996:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 997:
#   True: 슬픔, Predicted: 슬픔
# Image 998: No face detected.
# Image 999: No face detected.
# Image 1000: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 1001:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 39ms/step
# Image 1002:
#   True: 슬픔, Predicted: 분노
# Image 1003: No face detected.
# Image 1004: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 1005:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 1006:
#   True: 슬픔, Predicted: 기쁨
# Image 1007: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 1008:
#   True: 기쁨, Predicted: 기쁨
# Image 1009: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 1010:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 38ms/step
# Image 1011:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 1012:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 1013:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1014:
#   True: 슬픔, Predicted: 기쁨
# Image 1015: No face detected.
# Image 1016: No face detected.
# Image 1017: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 1018:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 45ms/step
# Image 1019:
#   True: 분노, Predicted: 기쁨
# Image 1020: No face detected.
# 1/1 [==============================] - 0s 51ms/step
# Image 1021:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1022:
#   True: 분노, Predicted: 기쁨
# Image 1023: No face detected.
# Image 1024: No face detected.
# 1/1 [==============================] - 0s 39ms/step
# Image 1025:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 39ms/step
# Image 1026:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1027:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 1028:
#   True: 기쁨, Predicted: 분노
# Image 1029: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 1030:
#   True: 슬픔, Predicted: 당황
# 1/1 [==============================] - 0s 38ms/step
# Image 1031:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 1032:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 1033:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1034:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1035:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1036:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 36ms/step
# Image 1037:
#   True: 당황, Predicted: 기쁨
# Image 1038: No face detected.
# Image 1039: No face detected.
# 1/1 [==============================] - 0s 41ms/step
# Image 1040:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1041:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1042:
#   True: 슬픔, Predicted: 기쁨
# Image 1043: No face detected.
# 1/1 [==============================] - 0s 41ms/step
# Image 1044:
#   True: 슬픔, Predicted: 기쁨
# Image 1045: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 1046:
#   True: 슬픔, Predicted: 슬픔
# Image 1047: No face detected.
# 1/1 [==============================] - 0s 36ms/step
# Image 1048:
#   True: 기쁨, Predicted: 기쁨
# Image 1049: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 1050:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1051:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 1052:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1053:
#   True: 슬픔, Predicted: 슬픔
# Image 1054: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 1055:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 1056:
#   True: 당황, Predicted: 당황
# 1/1 [==============================] - 0s 32ms/step
# Image 1057:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 33ms/step
# Image 1058:
#   True: 당황, Predicted: 슬픔
# Image 1059: No face detected.
# Image 1060: No face detected.
# 1/1 [==============================] - 0s 34ms/step
# Image 1061:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 1062:
#   True: 당황, Predicted: 분노
# 1/1 [==============================] - 0s 33ms/step
# Image 1063:
#   True: 기쁨, Predicted: 기쁨
# Image 1064: No face detected.
# Image 1065: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 1066:
#   True: 분노, Predicted: 기쁨
# Image 1067: No face detected.
# 1/1 [==============================] - 0s 30ms/step
# Image 1068:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1069:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1070:
#   True: 당황, Predicted: 분노
# Image 1071: No face detected.
# Image 1072: No face detected.
# Image 1073: No face detected.
# Image 1074: No face detected.
# 1/1 [==============================] - 0s 29ms/step
# Image 1075:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1076:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 38ms/step
# Image 1077:
#   True: 기쁨, Predicted: 기쁨
# Image 1078: No face detected.
# 1/1 [==============================] - 0s 37ms/step
# Image 1079:
#   True: 당황, Predicted: 기쁨
# Image 1080: No face detected.
# 1/1 [==============================] - 0s 41ms/step
# Image 1081:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1082:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 1083:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 1084:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 1085:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# Image 1086:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 1087:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 32ms/step
# Image 1088:
#   True: 슬픔, Predicted: 기쁨
# Image 1089: No face detected.
# 1/1 [==============================] - 0s 31ms/step
# Image 1090:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1091:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 1092:
#   True: 슬픔, Predicted: 기쁨
# Image 1093: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 1094:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1095:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 29ms/step
# Image 1096:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1097:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 35ms/step
# Image 1098:
#   True: 기쁨, Predicted: 기쁨
# Image 1099: No face detected.
# 1/1 [==============================] - 0s 33ms/step
# Image 1100:
#   True: 슬픔, Predicted: 기쁨
# Image 1101: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 1102:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1103:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1104:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 1105:
#   True: 당황, Predicted: 기쁨
# Image 1106: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 1107:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 38ms/step
# Image 1108:
#   True: 분노, Predicted: 기쁨
# Image 1109: No face detected.
# Image 1110: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 1111:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1112:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 37ms/step
# Image 1113:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 1114:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1115:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 36ms/step
# Image 1116:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 1117:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1118:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1119:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 1120:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 1121:
#   True: 기쁨, Predicted: 기쁨
# Image 1122: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 1123:
#   True: 슬픔, Predicted: 당황
# 1/1 [==============================] - 0s 46ms/step
# Image 1124:
#   True: 기쁨, Predicted: 기쁨
# Image 1125: No face detected.
# 1/1 [==============================] - 0s 44ms/step
# Image 1126:
#   True: 분노, Predicted: 당황
# 1/1 [==============================] - 0s 45ms/step
# Image 1127:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 42ms/step
# Image 1128:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 43ms/step
# Image 1129:
#   True: 분노, Predicted: 슬픔
# 1/1 [==============================] - 0s 47ms/step
# Image 1130:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 41ms/step
# Image 1131:
#   True: 슬픔, Predicted: 기쁨
# Image 1132: No face detected.
# 1/1 [==============================] - 0s 47ms/step
# Image 1133:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 44ms/step
# Image 1134:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 43ms/step
# Image 1135:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 45ms/step
# Image 1136:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 42ms/step
# Image 1137:
#   True: 당황, Predicted: 기쁨
# Image 1138: No face detected.
# Image 1139: No face detected.
# 1/1 [==============================] - 0s 47ms/step
# Image 1140:
#   True: 분노, Predicted: 기쁨
# Image 1141: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 1142:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 41ms/step
# Image 1143:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 45ms/step
# Image 1144:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 41ms/step
# Image 1145:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 45ms/step
# Image 1146:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 43ms/step
# Image 1147:
#   True: 분노, Predicted: 당황
# Image 1148: No face detected.
# 1/1 [==============================] - 0s 41ms/step
# Image 1149:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 39ms/step
# Image 1150:
#   True: 분노, Predicted: 분노
# Image 1151: No face detected.
# 1/1 [==============================] - 0s 44ms/step
# Image 1152:
#   True: 기쁨, Predicted: 기쁨
# Image 1153: No face detected.
# Image 1154: No face detected.
# 1/1 [==============================] - 0s 40ms/step
# Image 1155:
#   True: 당황, Predicted: 분노
# Image 1156: No face detected.
# Image 1157: No face detected.
# Image 1158: No face detected.
# 1/1 [==============================] - 0s 43ms/step
# Image 1159:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 43ms/step
# Image 1160:
#   True: 슬픔, Predicted: 분노
# Image 1161: No face detected.
# Image 1162: No face detected.
# Image 1163: No face detected.
# Image 1164: No face detected.
# Image 1165: No face detected.
# 1/1 [==============================] - 0s 44ms/step
# Image 1166:
#   True: 분노, Predicted: 기쁨
# Image 1167: No face detected.
# 1/1 [==============================] - 0s 41ms/step
# Image 1168:
#   True: 기쁨, Predicted: 기쁨
# Image 1169: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 1170:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 1171:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1172:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 1173:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 1174:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 41ms/step
# Image 1175:
#   True: 분노, Predicted: 기쁨
# Image 1176: No face detected.
# 1/1 [==============================] - 0s 38ms/step
# Image 1177:
#   True: 당황, Predicted: 슬픔
# 1/1 [==============================] - 0s 41ms/step
# Image 1178:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1179:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 39ms/step
# Image 1180:
#   True: 기쁨, Predicted: 분노
# 1/1 [==============================] - 0s 41ms/step
# Image 1181:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 41ms/step
# Image 1182:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 40ms/step
# Image 1183:
#   True: 분노, Predicted: 분노
# 1/1 [==============================] - 0s 38ms/step
# Image 1184:
#   True: 분노, Predicted: 분노
# Image 1185: No face detected.
# 1/1 [==============================] - 0s 35ms/step
# Image 1186:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 1187:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 1188:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 32ms/step
# Image 1189:
#   True: 기쁨, Predicted: 기쁨
# 1/1 [==============================] - 0s 35ms/step
# Image 1190:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 1191:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1192:
#   True: 분노, Predicted: 기쁨
# 1/1 [==============================] - 0s 33ms/step
# Image 1193:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 1194:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 34ms/step
# Image 1195:
#   True: 당황, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 1196:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 30ms/step
# Image 1197:
#   True: 슬픔, Predicted: 분노
# 1/1 [==============================] - 0s 33ms/step
# Image 1198:
#   True: 슬픔, Predicted: 기쁨
# 1/1 [==============================] - 0s 31ms/step
# Image 1199:
#   True: 분노, Predicted: 기쁨
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           기쁨       0.30      0.90      0.44       217
#           당황       0.61      0.12      0.21       200
#           분노       0.37      0.16      0.22       216
#           슬픔       0.33      0.09      0.14       219
#
#     accuracy                           0.32       852
#    macro avg       0.40      0.32      0.25       852
# weighted avg       0.40      0.32      0.25       852
#
#
# Confusion Matrix:
# [[195   1  15   6]
#  [137  25  20  18]
#  [157  10  34  15]
#  [171   5  24  19]]
